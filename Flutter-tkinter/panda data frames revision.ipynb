# %%
import pandas as pd

data = {
    "calories":[420,300,390],
    "duration":[50, 40, 45]
}

df = pd.DataFrame(data)

print(df)
# Out:
#    calories  duration
# 0       420        50
# 1       300        40
# 2       390        45
