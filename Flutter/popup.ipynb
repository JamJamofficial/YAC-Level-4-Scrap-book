# %%
from tkinter import *
master = Tk()
var1 = IntVar()
Checkbutton(master, text='Arsenal', variable=var1).gid(row=0, sticky=W)
var2 = IntVar()
Checkbutton(master, text='PSG', variable=var2).grid(row=1, sticky)
var3 = IntVar()
Checkbutton(master, text='BayernMunich', variable=var3).grid(row=2, sticky)
mainloop()
