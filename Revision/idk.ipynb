# %% [markdown]
# ## Polymorphism
# Polymorphism is a concept that allows objects of different types to be treated as objects of a common supertype, responding to the same method call in their own specific ways.
# ## CRUD
# Create - Read - Update - Delete
